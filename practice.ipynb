# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('Salary_dataset.csv')
df.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
X=df[['YearsExperience']]
Y=df['Salary']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)
Y_pred_1=model.predict(X_train)

# %%
sns.scatterplot(x=X_test.values.ravel(),y=Y_test,color='red',label='actual')
plt.plot(X_test.values.ravel(),Y_pred,color='blue',label='predicted')
plt.title('actual vs predicted salaray')
plt.legend()
plt.show()

# %%
print("MSE:",mean_squared_error(Y_pred,Y_test))
print("R^2:",r2_score(Y_pred,Y_test))
# Out:
# MSE: 38802588.99247057
# R^2: 0.9346100018376173

# %%
sns.scatterplot(x=df['YearsExperience'],y=df['Salary'],color='red',label='actual')
plt.plot(X_train,Y_pred_1,color='blue',label='predicted')
plt.title('actual vs predicted salaray')
plt.legend()
plt.show()

# %%
print("MSE:",mean_squared_error(Y_pred_1,Y_train))
print("R^2:",r2_score(Y_pred_1,Y_train))
# Out:
# MSE: 29332087.25131165
# R^2: 0.9533048696126198
